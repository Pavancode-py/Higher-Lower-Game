# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavancode-py/Higher-Lower-Game/blob/main/Gamedata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
logo='''
 __    __   __    _______  __    __   _______ .______
|  |  |  | |  |  /  _____||  |  |  | |   ____||   _  \
|  |__|  | |  | |  |  __  |  |__|  | |  |__   |  |_)  |
|   __   | |  | |  | |_ | |   __   | |   __|  |      /
|  |  |  | |  | |  |__| | |  |  |  | |  |____ |  |\  \----.
|__|  |__| |__|  \______| |__|  |__| |_______|| _| `._____|
 __        ______   ____    __    ____  _______ .______
|  |      /  __  \  \   \  /  \  /   / |   ____||   _  \
|  |     |  |  |  |  \   \/    \/   /  |  |__   |  |_)  |
|  |     |  |  |  |   \            /   |   __|  |      /
|  `----.|  `--'  |    \    /\    /    |  |____ |  |\  \----.
|_______| \______/      \__/  \__/     |_______|| _| `._____|
'''

# %%
vs='''
____    ____   _______.
\   \  /   /  /       |
 \   \/   /  |   (----`
  \      /    \   \
   \    / .----)   |
    \__/  |_______/
'''

# %%
data=[
    {
        "name": "Cristiano Ronaldo",
        "followers": 600000000,
        "description": "Footballer",
        "country": "Portugal"
    },
    {
        "name": "Instagram",
        "followers": 580000000,
        "description": "Social Media Platform",
        "country": "Global"
    },
    {
        "name": "Lionel Messi",
        "followers": 460000000,
        "description": "Footballer",
        "country": "Argentina"
    },
    {
        "name": "Selena Gomez",
        "followers": 420000000,
        "description": "Singer and Actress",
        "country": "USA"
    },
    {
        "name": "Dwayne Johnson",
        "followers": 390000000,
        "description": "Actor and Former Wrestler",
        "country": "USA"
    },
    {
        "name": "Kylie Jenner",
        "followers": 380000000,
        "description": "Businesswoman",
        "country": "USA"
    },
    {
        "name": "Kim Kardashian",
        "followers": 360000000,
        "description": "TV Personality",
        "country": "USA"
    },
    {
        "name": "Ariana Grande",
        "followers": 350000000,
        "description": "Singer",
        "country": "USA"
    },
    {
        "name": "Beyoncé",
        "followers": 310000000,
        "description": "Singer",
        "country": "USA"
    },
    {
        "name": "Neymar Jr.",
        "followers": 310000000,
        "description": "Footballer",
        "country": "Brazil"
    },
    {
        "name": "Taylor Swift",
        "followers": 290000000,
        "description": "Singer and Songwriter",
        "country": "USA"
    },
    {
        "name": "Justin Bieber",
        "followers": 290000000,
        "description": "Singer",
        "country": "Canada"
    },
    {
        "name": "Virat Kohli",
        "followers": 260000000,
        "description": "Cricketer",
        "country": "India"
    },
    {
        "name": "Kendall Jenner",
        "followers": 260000000,
        "description": "Model",
        "country": "USA"
    },
    {
        "name": "Jennifer Lopez",
        "followers": 250000000,
        "description": "Singer and Actress",
        "country": "USA"
    },
    {
        "name": "Nike",
        "followers": 270000000,
        "description": "Sportswear Brand",
        "country": "Global"
    },
    {
        "name": "LeBron James",
        "followers": 160000000,
        "description": "Basketball Player",
        "country": "USA"
    },
    {
        "name": "Shakira",
        "followers": 110000000,
        "description": "Singer",
        "country": "Colombia"
    },
    {
        "name": "NASA",
        "followers": 90000000,
        "description": "Space Agency",
        "country": "USA"
    },
    {
        "name": "Marvel",
        "followers": 80000000,
        "description": "Entertainment Franchise",
        "country": "Global"
    },
    {
        "name": "FC Barcelona",
        "followers": 120000000,
        "description": "Football Club",
        "country": "Spain"
    },
    {
        "name": "Real Madrid",
        "followers": 130000000,
        "description": "Football Club",
        "country": "Spain"
    },
    {
        "name": "Billie Eilish",
        "followers": 110000000,
        "description": "Singer",
        "country": "USA"
    },
    {
        "name": "Zendaya",
        "followers": 120000000,
        "description": "Actress",
        "country": "USA"
    },
    {
        "name": "Chris Hemsworth",
        "followers": 60000000,
        "description": "Actor",
        "country": "Australia"
    }
]
